# %% [markdown]
# 对于非线性可分的情况，SVM可以通过核函数（Kernel Function）将输入特征映射到高维空间，使得原本线性不可分的数据在高维空间中变得线性可分。
#
# ![image.png](attachment:f63d7969-4357-4dee-809f-0f381f9e9542.png)
#
#
# 常用的核函数包括线性核、多项式核、高斯核等。
#
#
# ![image.png](attachment:0369e4dd-9787-4777-a9ab-65c84108166a.png)

# %% [markdown]
# $\sigma$越小，模型复杂度越低
# $\sigma$越大，模型复杂度越高

# %%
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
from sklearn.svm import SVC

# %%
data=sio.loadmat('./data/ex6data2.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
X,y=data['X'],data['y']
X.shape,y.shape
# Out:
# ((863, 2), (863, 1))

# %%
def plot_data():
    plt.scatter(X[:,0],X[:,1],c=y.flatten(),cmap='jet')
    plt.xlabel('x1')
    plt.ylabel('y1')

# %%
plot_data()

# %%
svc1=SVC(C=1,kernel='rbf',gamma=1) # 使用高斯核
svc1.fit(X,y.flatten())
# Out:
# SVC(C=1, gamma=1)

# %%
svc1.score(X,y.flatten())
# Out:
# 0.8088064889918888

# %%
def plot_boundary(model):
    x_min,x_max=0,1
    y_min,y_max=0.4,1
    xx,yy=np.meshgrid(np.linspace(x_min,x_max,500),np.linspace(y_min,y_max,500))
    z=model.predict(np.c_[xx.flatten(),yy.flatten()])
    zz=z.reshape(xx.shape)
    plt.contour(xx,yy,zz)

# %%
plot_boundary(svc1)
plot_data()

# %%
svc50=SVC(C=1,kernel='rbf',gamma=50) # 使用高斯核
svc50.fit(X,y.flatten())
svc50.score(X,y.flatten())
plot_boundary(svc50)
plot_data()
